# %% [markdown]
# Filename: rrsInJupyterNotebooksDemo.ipynb
#
# Note: This is an adaptation of Dec4SimpleEvalRun.py

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import wandb
import weave
import inspect_wandb #this line is another test to see if inspect_wandb hasn't been uninstalled

wandb.init()

from inspect_ai import eval
from inspect_evals.ahb import ahb

eval(
    tasks = ahb,
    model = "together/meta-llama/Llama-3.2-3B-Instruct-Turbo",
    temperature = 0.7,
    max_connections = 50,
    #task_args={
    #    "grader_models": ["openai/o4-mini"],
    #    #"grader_temperature": 0.7, Note: some openai models don't accept temperature param
    #},
    epochs = 2,
)
# Out:
# inspect_ai v0.3.143
# - hooks enabled: 2
#   inspect_wandb/weave_evaluation_hooks: Weave evaluation integration
#   inspect_wandb/wandb_models_hooks: Weights & Biases model integration
# Output()
# weave: wandb version 0.23.1 is available!  To upgrade, please run:
# weave:  $ pip install wandb --upgrade
# weave: weave version 0.52.22 is available!  To upgrade, please run:
# weave:  $ pip install weave --upgrade
# weave: Logged in as Weights & Biases user: chen-joyee.
# weave: View Weave data at https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/weave
# wandb: Currently logged in as: chen-joyee (chen-joyee-team) to https://api.wandb.ai. Use `wandb login --relogin` to
# force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/joyeechen/ResearchRepo/welfare_defacc_prototyping_scripts/wandb/run-20251215_154216-XzYsJ8kNqyvAFYpYKfD2HK</code>
# Syncing run <strong><a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/runs/XzYsJ8kNqyvAFYpYKfD2HK' target="_blank">XzYsJ8kNqyvAFYpYKfD2HK</a></strong> to <a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping' target="_blank">https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping</a>
#  View run at <a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/runs/XzYsJ8kNqyvAFYpYKfD2HK' target="_blank">https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/runs/XzYsJ8kNqyvAFYpYKfD2HK</a>
# wandb: Initializing weave.
# Output()
# weave: Flushing 1 pending tasks...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# weave: wandb version 0.23.1 is available!  To upgrade, please run:
# weave:  $ pip install wandb --upgrade
# weave: weave version 0.52.22 is available!  To upgrade, please run:
# weave:  $ pip install weave --upgrade
# weave: Logged in as Weights & Biases user: chen-joyee.
# weave: View Weave data at https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/weave
# weave: retry_attempt
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>samples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0</td></tr><tr><td>samples</td><td>52</td></tr><tr><td>samples_correct</td><td>0</td></tr><tr><td>samples_total</td><td>52</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">XzYsJ8kNqyvAFYpYKfD2HK</strong> at: <a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/runs/XzYsJ8kNqyvAFYpYKfD2HK' target="_blank">https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping/runs/XzYsJ8kNqyvAFYpYKfD2HK</a><br> View project at: <a href='https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping' target="_blank">https://wandb.ai/chen-joyee-team/ResearchRepoPrototyping</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251215_154216-XzYsJ8kNqyvAFYpYKfD2HK/logs</code>

# %%
# %ls
# Out:
# Dec2prototypewithcolabgpucompute.ipynb
# Dec2prototypewithrunpodcompute.ipynb
# Dec2prototypewithtogetheraicompute.ipynb
# Dec4RepresentativeRandomSamplePrototyping.ipynb
# README.md
# logs/
# rrsInJupyterNotebooksDemo.ipynb
# wandb/
